# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/adslbbcc1023/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/adslbbcc1023/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /Users/adslbbcc1023/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/adslbbcc1023/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# Re: [新聞] 大甲媽百年首度南巡 韓國瑜今晚合體標哥吃平安宴
#
#
# WuSam
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 WuSam 的文章
#
#
#  2/15
#
#
#
#
#
#
# Re: [問卦] 為什麼台語的b容易聽成m而不是p?
#
#
# jksen
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jksen 的文章
#
#
#  2/15
#
#
#
#
# 7
#
# [問卦] 握力要怎麼練
#
#
# ss2121647
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ss2121647 的文章
#
#
#  2/15
#
#
#
#
# 3
#
# [新聞] 巴爾幹2敵對國達協議 建鐵公路連結兩首都
#
#
# FukubeSatosi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FukubeSatosi 的文章
#
#
#  2/15
#
#
#
#
#
#
# [問卦] 登入987次可以財富自由嗎
#
#
# jack97256
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jack97256 的文章
#
#
#  2/15
#
#
#
#
# 8
#
# [問卦] 日本是不是蠻慘的？
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  2/15
#
#
#
#
#
#
# [新聞] 「多從人道角度看武漢肺炎」　林祖嘉：
#
#
# mefenamic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 mefenamic 的文章
#
#
#  2/15
#
#
#
#
# 1
#
# Re: [新聞] （獨家）《國際橋牌社》燒盡7500萬 電視
#
#
# ILike58
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ILike58 的文章
#
#
#  2/15
#
#
#
#
#
#
# Re: [新聞] 陸配子女為何選中國籍？　醫護粉專曝5大
#
#
# losel
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 losel 的文章
#
#
#  2/15
#
#
#
#
# 7
#
# [問卦] 口罩可以自給自足後是不是可以外銷了
#
#
# vis64
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 vis64 的文章
#
#
#  2/15
#
#
#
#
#
#
#
# 				(本文已被刪除) [linaomasa]
#
#
#
# -
#
#
#  2/15
#
#
#
#
# 4
#
# Re: [新聞] 武漢肺炎》疫情影響捐血人變少 血庫架上都空了
#
#
# winnabe
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 winnabe 的文章
#
#
#  2/15
#
#
#
#
# 3
#
# Re: [新聞] 台商家屬嗆「防疫不是我們的事！」　萬人
#
#
# zizou
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zizou 的文章
#
#
#  2/15
#
#
#
#
#
#
# Re: [問卦] 登入987次可以財富自由嗎
#
#
# Rrrxddd
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Rrrxddd 的文章
#
#
#  2/15
#
#
#
#
# 1
#
# [新聞] 香港康美樓疫情結束 住戶可返家
#
#
# wenjames
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wenjames 的文章
#
#
#  2/15
#
#
#
#
#
#
# [問卦] 聽說過女朋友婚前送男方一棟全新透天嗎?
#
#
# Ho1liday
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ho1liday 的文章
#
#
#  2/15
#
#
#
#
#
#
# Re: [問卦] 男人真的不應該幫台女付錢
#
#
# ben780413
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ben780413 的文章
#
#
#  2/15
#
#
#
#
#
#
# [問卦] 農地用坪算價錢會太豪洨嗎
#
#
# Oral
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Oral 的文章
#
#
#  2/15
#
#
#
#
#
#
# [問卦] 手控女孩兒要不要看我手手
#
#
# Kimmy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Kimmy 的文章
#
#
#  2/15
#
#
#
#
#
# 5
#
# [公告] 關於板上疫情相關問卦&八卦板板規
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# X3
#
# [公告] 武漢肺炎討論專區&二月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  2/03
# M
#
#
#
# 42
#
# [公告] ★八卦板主投票開始了★
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  2/12
#
#
#
#
# 6
#
# [徵求] 行車記錄器 國道北上17.7K 晚上18:3
#
#
# berger200350
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 berger200350 的文章
#
#
#  2/12
#
#
#
#
# 11
#
# [徵求] 行車記錄器 台中市向上路6段往中沙路
#
#
# xodd123456
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 xodd123456 的文章
#
#
#  2/12
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/adslbbcc1023/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# Re: [新聞]「台灣野人」恆春半島吃不停 林管處盼吸收
#
#
# hltinokuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hltinokuo 的文章
#
#
#  7/29
#
#
#
#
# 3
#
# [問卦] 香港運輸物資居然用大隊接力！
#
#
# charco
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 charco 的文章
#
#
#  7/29
#
#
#
#
# 7
#
# [問卦] 有人會直接吃鮪魚罐頭嗎
#
#
# Antihuman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Antihuman 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 海底撈點這樣算摳嗎？
#
#
# danmitsu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 danmitsu 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 為什麼台灣找不到混血黑人球員??
#
#
# kerkerson
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kerkerson 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] 不會念書的人有女友嗎？
#
#
# Francise
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Francise 的文章
#
#
#  7/29
#
#
#
#
#
#
# [新聞] IZ*ONE熱潮狂掃《TGC 富山 2019》 八千人
#
#
# ATCTaiwan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ATCTaiwan 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# Re: [新聞] 回應韓國瑜 蔡英文：守護中華民國我說到
#
#
# cowardlyman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cowardlyman 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# [問卦] 農藥店真的很賺嗎？
#
#
# brucielu95
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucielu95 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] STU瀧野由美子終究只是個第三者嗎?
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  7/29
#
#
#
#
#
#
# Re: [問卦] 買私菸的官員會不會變成世紀罪人？
#
#
# fuxdk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fuxdk 的文章
#
#
#  7/29
#
#
#
#
# 6
#
# Re: [問卦] 俄羅斯小蘿莉在跳什麼舞？
#
#
# violinlife
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 violinlife 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 洗完雞雞容易激起性慾嗎
#
#
# dinex
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dinex 的文章
#
#
#  7/29
#
#
#
#
# 4
#
# [問卦] 為什麼教科書都要寫「偽」滿洲國？
#
#
# leopika
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leopika 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 假日時光倒流，想回去什麼時候
#
#
# blackzero1
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 blackzero1 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 台鐵補票事件是不是顯露部分台灣人醜陋?
#
#
# MizunaRei
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 MizunaRei 的文章
#
#
#  7/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.07.21)
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/21
# !
#
#
#
# 63
#
# [問卦]懇求7/19大溪往三峽路段死亡車禍行車紀錄
#
#
# nekosandy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nekosandy 的文章
#
#
#  7/21
# M
#
#
#
# 19
#
# [公告] 版規4-16修正草案
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  7/23
# M
#
#
#
# 87
#
# [尋人]尋人啟事 懇請幫忙
#
#
# skysea0940
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skysea0940 的文章
#
#
#  7/26
#
#
#
#
# 39
#
# [公告] 七月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/wei/.virtualenvs/py3/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
